# %%
import matplotlib.pyplot as plt

# %%
x = np.random.randint(1, 100)
print(x)
# Out:
# 48

# %%
x = [2000, 2005, 2009, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
y1 = [51, 50, 47, 52, 55.4, 50.7, 55.4, 51.5, 39.1, 42.7]
y2 = [26, 26, 20, 23, 21.4, 21, 22.6, 21.2, 21.2, 20.3]
y3 = [22, 11, 9, 9.2, 15.3, 12.8, 24.7, 17.2, 18.9, 22.8]
plt.plot(x, y1, label='Operations Research Analysts')
plt.plot(x, y2, label='Computer Programmers')
plt.plot(x, y3, label='Computer Hardware Engineers')
plt.xlabel('Year')
plt.ylabel('Percentage of Employed Women')
plt.title('How Women are Employed in Various Computer-Based Professions')
plt.legend()
plt.show()
